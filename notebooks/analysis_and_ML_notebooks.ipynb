# %%
# librairies loading

import os
import shutil

import numpy as np 
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, count, count_distinct, isnan,when

# %%
spark = SparkSession.builder.appName("Titanic Analysis").getOrCreate()

# %%
# dataset loading and saving
import kagglehub

# Download latest version
path = kagglehub.dataset_download("yasserh/titanic-dataset")

print("Path to dataset files:", path)
os.listdir(path)

#copy dataset into a local folder
kaggle_path = r"C:\Users\mayen\.cache\kagglehub\datasets\yasserh\titanic-dataset\versions\1\Titanic-Dataset.csv"
local_path = r"C:\Users\mayen\ML_DL_PROJECTS\Data_Analysis_and_ML_with_PySpark\data\titanic.csv"
shutil.copy(kaggle_path, local_path)
# Out:
# Path to dataset files: C:\Users\mayen\.cache\kagglehub\datasets\yasserh\titanic-dataset\versions\1
# 'C:\\Users\\mayen\\ML_DL_PROJECTS\\Data_Analysis_and_ML_with_PySpark\\data\\titanic.csv'

# %%
# print dataset 

data = spark.read.csv(local_path, header = True, inferSchema= True)

print("Number of lines :", data.count(), "Number of variables : ",len(data.columns))
data.show()
# Out:
# Number of lines : 891 Number of variables :  12
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# |PassengerId|Survived|Pclass|                Name|   Sex| Age|SibSp|Parch|          Ticket|   Fare|Cabin|Embarked|
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# |          1|       0|     3|Braund, Mr. Owen ...|  male|22.0|    1|    0|       A/5 21171|   7.25| NULL|       S|
# |          2|       1|     1|Cumings, Mrs. Joh...|female|38.0|    1|    0|        PC 17599|71.2833|  C85|       C|
# |          3|       1|     3|Heikkinen, Miss. ...|female|26.0|    0|    0|STON/O2. 3101282|  7.925| NULL|       S|
# |          4|       1|     1|Futrelle, Mrs. Ja...|female|35.0|    1|    0|          113803|   53.1| C123|       S|
# |          5|       0|     3|Allen, Mr. Willia...|  male|35.0|    0|    0|          373450|   8.05| NULL|       S|
# ...

# %%
data.printSchema()
# Out:
# root
#  |-- PassengerId: integer (nullable = true)
#  |-- Survived: integer (nullable = true)
#  |-- Pclass: integer (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Sex: string (nullable = true)
#  |-- Age: double (nullable = true)
#  |-- SibSp: integer (nullable = true)
#  |-- Parch: integer (nullable = true)
#  |-- Ticket: string (nullable = true)
#  |-- Fare: double (nullable = true)
#  |-- Cabin: string (nullable = true)
#  |-- Embarked: string (nullable = true)

# %%
data.columns
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']
